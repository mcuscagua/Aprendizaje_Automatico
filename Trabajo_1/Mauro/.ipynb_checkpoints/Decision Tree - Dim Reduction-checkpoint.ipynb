# %%
import numpy as np
import pandas as pd
import itertools as it
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import precision_score,confusion_matrix,recall_score,accuracy_score
from sklearn.metrics import roc_curve, auc,precision_recall_curve, roc_curve
import matplotlib.pylab as plt
from tsne import *

import plotly.graph_objects as go

from warnings import filterwarnings
filterwarnings('ignore')

# %%
Data = pd.read_excel('Data.xlsx')
Data = Data.set_index('Date')
Y = Data['Class']
X = Data.drop('Class', axis = 1)

# %% [markdown]
# ### Parameters

# %%
step = 100
ts_prop = 0.1
va_prop = 0.2

Hyper_Parameters = [[i for i in range(1,5)], # max_depth
                    [i for i in range(1,10)]] # min_samples_leaf
set_parameters = [i for i in it.product(*Hyper_Parameters)]
k = 5

# %% [markdown]
# #### Error real y de entrenamiento deseados

# %%
Epsilon = 0.15
delta = 0.15

# %% [markdown]
# #### Garantia probable de aprendizaje ($\eta_{estimado}$) y Tamaño optimo de la muestra $\eta_{optimo}$

# %% [markdown]
# #### $\eta_{estimado}$

# %%
n_est = int(np.ceil((1/Epsilon)*(np.log(len(set_parameters)) + np.log(1/delta))))

# %% [markdown]
# #### $\eta_{optimo}$

# %%
n_opt = int((np.log(2)/(2*Epsilon**2))*((2**k - 1)*(1 + np.log2(X.shape[1])) + 1 + np.log(delta**(-1))))

# %% [markdown]
# #### Division del conjunto: entrenamiento (70%), validacion (20%) y prueba (10%)

# %%
X1, X1_ts, Y1,Y1_ts = train_test_split(X, Y, train_size = 1-ts_prop, random_state=19)
X1_tr, X1_va, Y1_tr, Y1_va = train_test_split(X1, Y1, train_size = 1-va_prop, random_state=19)

# %% [markdown]
# #### Discretizacion para explorar el aumento de $\eta$

# %%
N = range(n_est, round(X1_tr.shape[0]*(1-va_prop)), step)

# %% [markdown]
# ### Exploracion de modelos partiendo de $\eta_{estimado}$, es claro que $\eta_{estimado}$ es tenido en cuenta ya que $\eta_{estimado} < \eta_{optimo}$

# %%
n_est_mod_results = {
    'Model': [None for i in range(len(set_parameters))],
    'Accuracy': np.zeros((len(N),len(set_parameters))),
    'Precision': np.zeros((len(N),len(set_parameters))),
    'Recall': np.zeros((len(N),len(set_parameters)))
}

# %%
for j in range(len(set_parameters)):
    dtc = DecisionTreeClassifier(max_depth = set_parameters[j][0], min_samples_leaf= set_parameters[j][1], random_state=19)
    for i in range(len(N)):
        np.random.seed(seed = 19)
        ind1 = np.random.randint(0, X1_tr.shape[0], N[i])
        dtc.fit(X1_tr.iloc[ind1,], Y1_tr[ind1])
        y_pred = dtc.predict(X1_va)
        n_est_mod_results['Accuracy'][i,j] = accuracy_score(Y1_va, y_pred)
        n_est_mod_results['Precision'][i,j] = precision_score(Y1_va, y_pred, average = 'macro')
        n_est_mod_results['Recall'][i,j] = recall_score(Y1_va, y_pred, average = 'macro')
    n_est_mod_results['Model'][j] = dtc
    
ind_bst = np.where(n_est_mod_results['Accuracy'] == np.amax(n_est_mod_results['Accuracy']))[1][0]
n_est_mod_results['Best'] = set_parameters[ind_bst]

# %% [markdown]
# #### Grid search

# %%
Hyper_Parameters = {
    'max_depth': [i for i in range(1,5)],
    'min_samples_leaf': [i for i in range(1,10)]
}
clf = GridSearchCV(DecisionTreeClassifier(), Hyper_Parameters, cv = 5)
clf.fit(X1_tr.values, Y1_tr)
clf.best_params_
# Out:
# {'max_depth': 4, 'min_samples_leaf': 1}

# %%
fig1 = go.Figure(data=[go.Surface(z=n_est_mod_results['Accuracy'])])

fig1.update_layout(title='Accuracy Surface', autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))

fig1.show()
# Out:
# <div>
#
#
#             <div id="666c4b42-e432-48be-b507-b433a8c99bf9" class="plotly-graph-div" style="height:500px; width:500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("666c4b42-e432-48be-b507-b433a8c99bf9")) {
#                     Plotly.newPlot(
#                         '666c4b42-e432-48be-b507-b433a8c99bf9',
#                         [{"type": "surface", "z": [[0.49099099099099097, 0.49099099099099097, 0.49099099099099097, 0.49099099099099097, 0.49099099099099097, 0.49099099099099097, 0.49099099099099097, 0.49099099099099097, 0.49099099099099097, 0.40653153153153154, 0.40653153153153154, 0.40653153153153154, 0.40653153153153154, 0.40653153153153154, 0.43243243243243246, 0.43243243243243246, 0.43243243243243246, 0.49099099099099097, 0.4155405405405405, 0.4189189189189189, 0.40202702702702703, 0.40315315315315314, 0.40653153153153154, 0.43243243243243246, 0.43243243243243246, 0.43243243243243246, 0.49099099099099097, 0.43243243243243246, 0.4560810810810811, 0.40202702702702703, 0.40315315315315314, 0.40653153153153154, 0.43243243243243246, 0.43243243243243246, 0.43243243243243246, 0.49099099099099097], [0.49774774774774777, 0.49774774774774777, 0.49774774774774777, 0.49774774774774777, 0.49774774774774777, 0.49774774774774777, 0.49774774774774777, 0.49774774774774777, 0.49774774774774777, 0.5281531531531531, 0.5281531531531531, 0.5337837837837838, 0.5337837837837838, 0.5337837837837838, 0.5337837837837838, 0.5337837837837838, 0.5337837837837838, 0.5337837837837838, 0.5056306306306306, 0.5056306306306306, 0.46846846846846846, 0.48536036036036034, 0.48536036036036034, 0.481981981981982, 0.48986486486486486, 0.46283783783783783, 0.46283783783783783, 0.4650900900900901, 0.4650900900900901, 0.44819819819819817, 0.4583333333333333, 0.4650900900900901, 0.46846846846846846, 0.5, 0.4583333333333333, 0.4583333333333333], [0.46959459459459457, 0.46959459459459457, 0.46959459459459457, 0.46959459459459457, 0.46959459459459457, 0.46959459459459457, 0.46959459459459457, 0.46959459459459457, 0.46959459459459457, 0.5180180180180181, 0.5180180180180181, 0.5180180180180181, 0.5180180180180181, 0.5180180180180181, 0.5180180180180181, 0.5180180180180181, 0.49774774774774777, 0.49774774774774777, 0.4346846846846847, 0.4346846846846847, 0.4346846846846847, 0.4369369369369369, 0.4369369369369369, 0.4369369369369369, 0.4369369369369369, 0.42454954954954954, 0.42117117117117114, 0.44707207207207206, 0.44707207207207206, 0.44707207207207206, 0.42454954954954954, 0.42454954954954954, 0.42567567567567566, 0.42567567567567566, 0.4166666666666667, 0.4132882882882883], [0.48873873873873874, 0.48873873873873874, 0.48873873873873874, 0.48873873873873874, 0.48873873873873874, 0.48873873873873874, 0.48873873873873874, 0.48873873873873874, 0.48873873873873874, 0.5135135135135135, 0.5135135135135135, 0.5135135135135135, 0.5135135135135135, 0.5135135135135135, 0.5123873873873874, 0.5, 0.5, 0.5, 0.509009009009009, 0.509009009009009, 0.509009009009009, 0.509009009009009, 0.509009009009009, 0.5078828828828829, 0.509009009009009, 0.4954954954954955, 0.4954954954954955, 0.49324324324324326, 0.49324324324324326, 0.49324324324324326, 0.5011261261261262, 0.5, 0.5045045045045045, 0.49211711711711714, 0.4786036036036036, 0.4786036036036036], [0.48873873873873874, 0.48873873873873874, 0.48873873873873874, 0.48873873873873874, 0.48873873873873874, 0.48873873873873874, 0.48873873873873874, 0.48873873873873874, 0.48873873873873874, 0.5123873873873874, 0.5123873873873874, 0.5123873873873874, 0.5123873873873874, 0.5123873873873874, 0.5123873873873874, 0.5123873873873874, 0.5123873873873874, 0.5123873873873874, 0.49774774774774777, 0.49774774774774777, 0.4966216216216216, 0.49774774774774777, 0.49774774774774777, 0.49774774774774777, 0.49774774774774777, 0.49774774774774777, 0.49774774774774777, 0.49324324324324326, 0.49324324324324326, 0.49211711711711714, 0.48536036036036034, 0.48536036036036034, 0.48423423423423423, 0.49324324324324326, 0.49324324324324326, 0.49324324324324326], [0.4864864864864865, 0.4864864864864865, 0.4864864864864865, 0.4864864864864865, 0.4864864864864865, 0.4864864864864865, 0.4864864864864865, 0.4864864864864865, 0.4864864864864865, 0.5112612612612613, 0.5112612612612613, 0.5112612612612613, 0.5112612612612613, 0.5112612612612613, 0.5112612612612613, 0.511261261 ...

# %%
fig2 = go.Figure(data=[go.Surface(z=n_est_mod_results['Precision'])])

fig2.update_layout(title='Precision', autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))

fig2.show()
# Out:
# <div>
#
#
#             <div id="dcb03965-1918-4f36-8e9b-f96a5e873fe7" class="plotly-graph-div" style="height:500px; width:500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dcb03965-1918-4f36-8e9b-f96a5e873fe7")) {
#                     Plotly.newPlot(
#                         'dcb03965-1918-4f36-8e9b-f96a5e873fe7',
#                         [{"type": "surface", "z": [[0.2909560723514212, 0.2909560723514212, 0.2909560723514212, 0.2909560723514212, 0.2909560723514212, 0.2909560723514212, 0.2909560723514212, 0.2909560723514212, 0.2909560723514212, 0.3547514217574757, 0.3547514217574757, 0.3547514217574757, 0.3547514217574757, 0.3547514217574757, 0.40913012184714, 0.40913012184714, 0.40913012184714, 0.2909560723514212, 0.33353096527642023, 0.3345774767557595, 0.33069270449521, 0.32978908124965567, 0.3547514217574757, 0.40913012184714, 0.40913012184714, 0.40913012184714, 0.2909560723514212, 0.34410155166261536, 0.3577708409883542, 0.33069270449521, 0.32978908124965567, 0.3547514217574757, 0.40913012184714, 0.40913012184714, 0.40913012184714, 0.2909560723514212], [0.32855452463295604, 0.32855452463295604, 0.32855452463295604, 0.32855452463295604, 0.32855452463295604, 0.32855452463295604, 0.32855452463295604, 0.32855452463295604, 0.32855452463295604, 0.4129464473164874, 0.4129464473164874, 0.32859384272695497, 0.32859384272695497, 0.32859384272695497, 0.32859384272695497, 0.32859384272695497, 0.32859384272695497, 0.32859384272695497, 0.4500228223659186, 0.4500228223659186, 0.4177528941766541, 0.4269047619047619, 0.4269047619047619, 0.4269769363684171, 0.44016817009684855, 0.44377019715214333, 0.44377019715214333, 0.3967693021107179, 0.3967693021107179, 0.39502231298691476, 0.40504938195766865, 0.40441951157141026, 0.4073476702508961, 0.43216578525008553, 0.4252879277487778, 0.4252879277487778], [0.33138238573021184, 0.33138238573021184, 0.33138238573021184, 0.33138238573021184, 0.33138238573021184, 0.33138238573021184, 0.33138238573021184, 0.33138238573021184, 0.33138238573021184, 0.31250544662309365, 0.31250544662309365, 0.31250544662309365, 0.31250544662309365, 0.31250544662309365, 0.31250544662309365, 0.31250544662309365, 0.3024540295340166, 0.3024540295340166, 0.39263347763347767, 0.39263347763347767, 0.39263347763347767, 0.3949607108761108, 0.3949607108761108, 0.3949607108761108, 0.3949607108761108, 0.388817092947577, 0.386938964369838, 0.41317570119798086, 0.412739315614785, 0.41317570119798086, 0.3971083182823087, 0.3971083182823087, 0.39818407180457277, 0.39818407180457277, 0.4024115024115024, 0.4003187259435517], [0.3396637973150576, 0.3396637973150576, 0.3396637973150576, 0.3396637973150576, 0.3396637973150576, 0.3396637973150576, 0.3396637973150576, 0.3396637973150576, 0.3396637973150576, 0.39755972861308014, 0.39755972861308014, 0.39755972861308014, 0.39755972861308014, 0.39755972861308014, 0.3783567576138202, 0.3713213756481673, 0.3713213756481673, 0.3713213756481673, 0.46650713213213213, 0.46650713213213213, 0.46650713213213213, 0.46650713213213213, 0.46650713213213213, 0.4611323696145125, 0.46649227469598536, 0.4443588969404187, 0.4443588969404187, 0.44598852233076497, 0.44598852233076497, 0.44598852233076497, 0.4482947586833828, 0.44718035456994304, 0.4456032992038496, 0.44690202517788724, 0.437565643613675, 0.437565643613675], [0.3323554976097349, 0.3323554976097349, 0.3323554976097349, 0.3323554976097349, 0.3323554976097349, 0.3323554976097349, 0.3323554976097349, 0.3323554976097349, 0.3323554976097349, 0.3255053991856966, 0.3255053991856966, 0.3255053991856966, 0.3255053991856966, 0.3255053991856966, 0.3255053991856966, 0.3255053991856966, 0.3255053991856966, 0.3255053991856966, 0.41873696678511246, 0.41873696678511246, 0.4175422429563076, 0.4182653970586177, 0.4182653970586177, 0.4182653970586177, 0.4182653970586177, 0.4182653970586177, 0.4182653970586177, 0.40444582977334065, 0.40444582977334065, 0.40321006294600686, 0.3985290330117916, 0.3985290330117916, 0.39776166862485907, 0.4040036404106679, 0.4040036404106679, 0.4040036404106679], [0.3313153549807375, 0.3313153549807375, 0.3313153549807375, 0.3313153549807375, 0.3313153549807375, 0.3313153549807375, 0.3313153549807375, 0.3313153549807375, 0.3313153549807375, 0.3249030437112374, 0.3249030437112374, 0.3249030437112374, 0.3249030437112374, 0.3249030437112374, 0.32490304371 ...

# %%
fig3 = go.Figure(data=[go.Surface(z=n_est_mod_results['Recall'])])

fig3.update_layout(title='Recall', autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))

fig3.show()
# Out:
# <div>
#
#
#             <div id="840cf63c-cdb2-4fea-aadd-3f86f4e3ce4d" class="plotly-graph-div" style="height:500px; width:500px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("840cf63c-cdb2-4fea-aadd-3f86f4e3ce4d")) {
#                     Plotly.newPlot(
#                         '840cf63c-cdb2-4fea-aadd-3f86f4e3ce4d',
#                         [{"type": "surface", "z": [[0.3971791798013882, 0.3971791798013882, 0.3971791798013882, 0.3971791798013882, 0.3971791798013882, 0.3971791798013882, 0.3971791798013882, 0.3971791798013882, 0.3971791798013882, 0.34626159925409583, 0.34626159925409583, 0.34626159925409583, 0.34626159925409583, 0.34626159925409583, 0.3987341951683958, 0.3987341951683958, 0.3987341951683958, 0.3971791798013882, 0.3317358921990854, 0.32946414036022437, 0.3227439111624167, 0.32220828585100664, 0.34626159925409583, 0.3987341951683958, 0.3987341951683958, 0.3987341951683958, 0.3971791798013882, 0.3460585968910792, 0.3534863127568362, 0.3227439111624167, 0.32220828585100664, 0.34626159925409583, 0.3987341951683958, 0.3987341951683958, 0.3987341951683958, 0.3971791798013882], [0.42592800199302444, 0.42592800199302444, 0.42592800199302444, 0.42592800199302444, 0.42592800199302444, 0.42592800199302444, 0.42592800199302444, 0.42592800199302444, 0.42592800199302444, 0.4211120607576453, 0.4211120607576453, 0.42033507722969604, 0.42033507722969604, 0.42033507722969604, 0.42033507722969604, 0.42033507722969604, 0.42033507722969604, 0.42033507722969604, 0.44199096479154637, 0.44199096479154637, 0.4188715732559803, 0.42944083085438584, 0.42944083085438584, 0.42990702097115546, 0.44312141415935313, 0.421906557247653, 0.421906557247653, 0.3941300127770624, 0.3941300127770624, 0.3927308874385196, 0.40394787797165366, 0.4033001450369252, 0.4063261258861312, 0.4280367106217348, 0.40159639282313875, 0.40159639282313875], [0.42392252117588436, 0.42392252117588436, 0.42392252117588436, 0.42392252117588436, 0.42392252117588436, 0.42392252117588436, 0.42392252117588436, 0.42392252117588436, 0.42392252117588436, 0.3970416043846537, 0.3970416043846537, 0.3970416043846537, 0.3970416043846537, 0.3970416043846537, 0.3970416043846537, 0.3970416043846537, 0.3906452416542103, 0.3906452416542103, 0.3906042958555946, 0.3906042958555946, 0.3906042958555946, 0.39338207363337235, 0.39338207363337235, 0.39338207363337235, 0.39338207363337235, 0.38580235265679036, 0.3835602001904226, 0.40899401599352764, 0.40873273986591485, 0.40899401599352764, 0.391195666651867, 0.391195666651867, 0.3925845555407559, 0.3925845555407559, 0.39857744182489996, 0.3963352893585323], [0.43726955655206773, 0.43726955655206773, 0.43726955655206773, 0.43726955655206773, 0.43726955655206773, 0.43726955655206773, 0.43726955655206773, 0.43726955655206773, 0.43726955655206773, 0.37494924940924584, 0.37494924940924584, 0.37494924940924584, 0.37494924940924584, 0.37494924940924584, 0.37420186525378996, 0.3704945438490037, 0.3704945438490037, 0.3704945438490037, 0.4496752702176048, 0.4496752702176048, 0.4496752702176048, 0.4496752702176048, 0.4496752702176048, 0.44892788606214884, 0.4523836128007419, 0.4452205646573626, 0.4452205646573626, 0.4498540997597517, 0.4498540997597517, 0.4498540997597517, 0.4514746654037601, 0.45072728124830425, 0.449202913564899, 0.44882206830548527, 0.44165902016210584, 0.44165902016210584], [0.428288490284006, 0.428288490284006, 0.428288490284006, 0.428288490284006, 0.428288490284006, 0.428288490284006, 0.428288490284006, 0.428288490284006, 0.428288490284006, 0.42409691081215745, 0.42409691081215745, 0.42409691081215745, 0.42409691081215745, 0.42409691081215745, 0.42409691081215745, 0.42409691081215745, 0.42409691081215745, 0.42409691081215745, 0.4218389720137932, 0.4218389720137932, 0.42045008312490445, 0.4211974672803603, 0.4211974672803603, 0.4211974672803603, 0.4211974672803603, 0.4211974672803603, 0.4211974672803603, 0.40057928438583773, 0.40057928438583773, 0.39919039549694885, 0.3947060905642134, 0.3947060905642134, 0.3939587064087575, 0.3999377796524048, 0.3999377796524048, 0.3999377796524048], [0.4267937219730942, 0.4267937219730942, 0.4267937219730942, 0.4267937219730942, 0.4267937219730942, 0.4267937219730942, 0.4267937219730942, 0.4267937219730942, 0.4267937219730942, 0.4233495266567015, 0.4233495266567015, 0.4233495266567015, 0.4233495266567015, 0.4233 ...
